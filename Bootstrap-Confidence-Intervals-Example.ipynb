# %%
#import libraries 
import numpy
from pandas import read_csv
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from matplotlib import pyplot

# %%
# Load CSV (dataset using Pandas from URL
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
data = pandas.read_csv(url, header=None)
values = data.values

# %%
# configure bootstrap, going to use 1000 iterations
n_iterations = 1000
n_size = int(len(data) * 0.50)

# %%
#run boostrap and iterate over it
stats = list()
for i in range(n_iterations):
	# prepare train and test sets
	train = resample(values, n_samples=n_size)
	test = numpy.array([x for x in values if x.tolist() not in train.tolist()])
	# fit model
	model = DecisionTreeClassifier()
	model.fit(train[:,:-1], train[:,-1])
	# evaluate model
	predictions = model.predict(test[:,:-1])
	score = accuracy_score(test[:,-1], predictions)
	print(score)
	stats.append(score)
# Out:
# 0.6708860759493671
# 0.7109207708779444
# 0.6582809224318659
# 0.6879120879120879
# 0.6595289079229122
# 0.6545064377682404
# 0.6558441558441559
# 0.6805251641137856
# 0.708779443254818
# 0.6753246753246753
# 0.6850220264317181
# 0.6904761904761905
# 0.6828193832599119
# 0.728421052631579
# 0.6797385620915033
# 0.6652452025586354
# 0.6908315565031983
# 0.6845493562231759
# 0.7133620689655172
# 0.6974789915966386
# 0.6715481171548117
# 0.6659340659340659
# 0.6788793103448276
# 0.6946236559139785
# 0.6595289079229122
# 0.6751054852320675
# 0.7569892473118279
# 0.6710526315789473
# 0.6948051948051948
# 0.6405919661733616
# 0.6985138004246284
# 0.6861471861471862
# 0.70995670995671
# 0.7042553191489361
# 0.6540084388185654
# 0.6851063829787234
# 0.7142857142857143
# 0.6638297872340425
# 0.6680851063829787
# 0.6680851063829787
# 0.6207627118644068
# 0.6797385620915033
# 0.6573875802997858
# 0.6717724288840262
# 0.7065217391304348
# 0.6954643628509719
# 0.7100840336134454
# ...

# %%
# plot scores
pyplot.hist(stats)
pyplot.show()

# %%
# confidence intervals
alpha = 0.95
p = ((1.0-alpha)/2.0) * 100
lower = max(0.0, numpy.percentile(stats, p))
p = (alpha+((1.0-alpha)/2.0)) * 100
upper = min(1.0, numpy.percentile(stats, p))

# %%
# prints out the classification accuracy of each bootstrap iteration
print('%.1f confidence interval %.1f%% and %.1f%%' % (alpha*100, lower*100, upper*100))
# Out:
# 95.0 confidence interval 68.0% and 68.0%

# %%
# Out:
# 0.6744186046511628
# 0.6746203904555315
# 0.6645435244161358
# 0.6980306345733042
# 0.6981132075471698
# 0.6948051948051948
# 0.717948717948718
# 0.6970338983050848
# 0.6948051948051948
# 0.6929637526652452
# 0.725531914893617
# 0.6836518046709129
# 0.6779661016949152
# 0.6914893617021277
# 0.7152173913043478
# 0.7239915074309978
# 0.695364238410596
# 0.6954643628509719
# 0.6523605150214592
# 0.6788008565310493
# 0.6876355748373102
# 0.6772151898734177
# 0.7176724137931034
# 0.7076923076923077
# 0.7245762711864406
# 0.717948717948718
# 0.720173535791757
# 0.6899563318777293
# 0.6475770925110133
# 0.6997885835095138
# 0.7106382978723405
# 0.7060085836909872
# 0.7341772151898734
# 0.7117903930131004
# 0.6390658174097664
# 0.7133620689655172
# 0.6872340425531915
# 0.6483050847457628
# 0.6918238993710691
# 0.6928104575163399
# 0.6927966101694916
# 0.6559139784946236
# 0.6955602536997886
# 0.6666666666666666
# 0.7051282051282052
# 0.6645161290322581
# 0.6829787234042554
# ...
